# %%
import pandas as pd
import numpy as np
from IPython.display import display, clear_output

from data import (
    load_dataset,
    dataset_info,
    summary_statistics,
    general_health_to_numeric,
    age_category_to_numeric,
    binary_columns_to_numeric,
    checkup_to_numeric,
    preprocess,
    plot_numeric_distributions,
    plot_normality_qq,
    plot_categorical_distributions,
)

from regression import (
    run_linear,
    run_xgboost,
    run_random_forest,
    run_ridge,
    run_gradient_boosting,
    compare_models,
    plot_correlation,
    spearman_correlation,
    mann_whitney_u_correlation,
    pearson_correlation,
    check_normality,
    make_everyone_exercise
)

df = load_dataset("data/data.csv")

# %% [markdown]
# # Numerične spremenljivke
# Numerične spremenljivke so:
# - BMI: indeks med telesno težo in višino, višji BMI je ponavadi slabši za zdravje.
# - Spremenljivke ki omenjajo sadje, alkohol, pražen krompir in zeleno zelenjavo nam povejo koliko konzumirajo na tedenski ravni.
# - Height_(cm) in Weight_(kg) nam poveta koliko je teža in višina, uporabijo se za izračun BMI.

# %%
plot_numeric_distributions(df)

# %% [markdown]
# # Kategorične spremenljivke
# - Heart_Disease nam pove če ima srčno bolezen.
# - Smoking_History nam pove če ima zgodovino kajenja, vendar je to lahko zavajujoče saj nam ne pove kako dolgo nazaj je to bilo in če še vedno kadijo.
# - Exercise: Če so v zadnjem času telovadili.
# - Sex: spol
# - Diabetes: če imajo diabetis
# - Depression: če imajo simptome depresije
# - Arthritis: če imajo artritis
# - General_Health: to je ocena ki jo udeleženec sam poda o tem kako dobro je njegovo zdravje.
# - Age_Category nam pove v katero kategorijo starosti spadajo udeleženci, iz grafa vidimo da so večinoma starejši.

# %%
plot_categorical_distributions(df)

# %% [markdown]
# # Q-Q grafi normalnosti
# Iz grafov se vidi da je veliko udeležencev reklo da pije ali zelo veliko alkohola ali pa zelo malo, podobno je bilo s sadjem, zelenjavo in krompirjem. Pri ostalih je graf kot pričakovan.

# %%
plot_normality_qq(df)

# %% [markdown]
# # Predprocesiranje podatkov
# Tukaj smo odstranili vrstice brez podatkov in enkodirali kategorične spremenljivke v števila.

# %% [markdown]
# ## Manjkajoči podatki

# %%
missing_by_col = df.isna().sum().sort_values(ascending=False)
missing_total = int(missing_by_col.sum())
missing_by_col, missing_total
# Out:
# (General_Health                  0
#  Checkup                         0
#  Exercise                        0
#  Heart_Disease                   0
#  Skin_Cancer                     0
#  Other_Cancer                    0
#  Depression                      0
#  Diabetes                        0
#  Arthritis                       0
#  Sex                             0
#  Age_Category                    0
#  Height_(cm)                     0
#  Weight_(kg)                     0
#  BMI                             0
#  Smoking_History                 0
#  Alcohol_Consumption             0
#  Fruit_Consumption               0
#  Green_Vegetables_Consumption    0
#  FriedPotato_Consumption         0
#  dtype: int64,
#  0)

# %% [markdown]
# ## Duplikati

# %% [markdown]
# Enaki odgovori so mogoči pri različnih osebah, zato jih ne odstranjujemo. Posamezniki niso označeni z identifikacijo.

# %%
int(df.duplicated().sum())
# Out:
# 80

# %% [markdown]
# ## Predprocesiranje

# %% [markdown]
# Kategoričnim spremenljivkam najprej dodelimo številske vrednosti.

# %%
df = preprocess(df)

# %%
num_cols = df.select_dtypes(include="number").columns
minmax = df[num_cols].agg(["min","max"]).T
minmax
# Out:
#                                 min     max
# General_Health                 1.00    5.00
# Checkup                        0.00    1.00
# Exercise                       0.00    1.00
# Heart_Disease                  0.00    1.00
# Skin_Cancer                    0.00    1.00
# Other_Cancer                   0.00    1.00
# Depression                     0.00    1.00
# Diabetes                       0.00    1.00
# Arthritis                      0.00    1.00
# Sex                            0.00    1.00
# Age_Category                  21.00   82.00
# Height_(cm)                   91.00  241.00
# Weight_(kg)                   24.95  293.02
# BMI                           12.02   99.33
# Smoking_History                0.00    1.00
# Alcohol_Consumption            0.00   30.00
# Fruit_Consumption              0.00  120.00
# Green_Vegetables_Consumption   0.00  128.00
# FriedPotato_Consumption        0.00  128.00

# %% [markdown]
# Ekstremi so realni zato jih ne odstranjujemo. Najvišji človek v zgodovini je visok 272 cm, zato naš 241 cm ne izstopa. Zelo majhna višina ali teža sta lahko posledici zdravstvenih stanj, prav tako visoka teža/BMI.

# %% [markdown]
# # Regresija - BMI
# V regresiji je odvisna spremenljivka BMI. Ker se teža in višina uporabljata za izračun BMI, te izpustimo.

# %% [markdown]
# ## Korelacija med BMI in pomembnimi spremenljivkami

# %%
check_normality(df, ["BMI", "Alcohol_Consumption", "Fruit_Consumption", "Green_Vegetables_Consumption", "FriedPotato_Consumption", "General_Health", "Age_Category"])
# Out:
#                        Variable     Shapiro_p Normal  N_unique
# 6                  Age_Category  4.164306e-38     NO        13
# 1           Alcohol_Consumption  2.693447e-72     NO        29
# 0                           BMI  5.759612e-42     NO      1137
# 4       FriedPotato_Consumption  4.076517e-76     NO        29
# 2             Fruit_Consumption  7.707599e-56     NO        35
# 5                General_Health  1.246990e-49     NO         5
# 3  Green_Vegetables_Consumption  6.378681e-64     NO        38

# %%
mann_whitney_u_correlation(df, ["Heart_Disease", "Smoking_History", "Exercise", "Skin_Cancer", "Other_Cancer", "Depression", "Diabetes", "Arthritis", "Sex", "Checkup"])
# Out:
#            Feature   U_statistic        p_value  Median_BMI_0  Median_BMI_1
# 2         Exercise  9.936235e+09   0.000000e+00         29.26         27.12
# 7        Arthritis  8.698598e+09   0.000000e+00         27.05         28.74
# 6         Diabetes  3.375525e+09   0.000000e+00         27.12         30.85
# 5       Depression  6.656267e+09   0.000000e+00         27.34         28.75
# 9          Checkup  7.479164e+09   0.000000e+00         26.63         27.71
# 0    Heart_Disease  3.166298e+09  1.934898e-172         27.44         28.55
# 8              Sex  1.124022e+10  7.293510e-160         27.37         27.80
# 3      Skin_Cancer  4.438350e+09   2.534223e-68         27.46         27.06
# 1  Smoking_History  1.108117e+10   5.465959e-66         27.40         27.71
# 4     Other_Cancer  4.136852e+09   3.565470e-02         27.44         27.46

# %%
spearman_correlation(df, ["Alcohol_Consumption", "Fruit_Consumption", "Green_Vegetables_Consumption", "FriedPotato_Consumption"])
# Out:
#                         Feature  Spearman_rho  p_value
# 0           Alcohol_Consumption     -0.095380      0.0
# 3       FriedPotato_Consumption      0.093054      0.0
# 1             Fruit_Consumption     -0.089118      0.0
# 2  Green_Vegetables_Consumption     -0.071518      0.0

# %%
plot_correlation(df)

# %% [markdown]
# ## Izbira pomembnih spremenljivk

# %% [markdown]
# ### XGBoost

# %%
xgb_model, xgb_importance_df, xgb_rmse_mean, xgb_rmse_std, xgb_r2 = run_xgboost(df)
print(f"XGBoost RMSE: {xgb_rmse_mean:.3f}, R²: {xgb_r2:.3f}")
xgb_importance_df
# Out:
# XGBoost RMSE: 36.003, R²: 0.141
# <style type="text/css">
# #T_90d83_row0_col1, #T_90d83_row1_col1, #T_90d83_row2_col1, #T_90d83_row3_col1, #T_90d83_row4_col1 {
#   background-color: #90EE90;
#   font-weight: bold;
# }
# </style>
# <table id="T_90d83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90d83_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_90d83_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90d83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90d83_row0_col0" class="data row0 col0" >Diabetes</td>
#       <td id="T_90d83_row0_col1" class="data row0 col1" >0.433521</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90d83_row1_col0" class="data row1 col0" >Arthritis</td>
#       <td id="T_90d83_row1_col1" class="data row1 col1" >0.135183</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90d83_row2_col0" class="data row2 col0" >Exercise</td>
#       <td id="T_90d83_row2_col1" class="data row2 col1" >0.125549</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90d83_row3_col0" class="data row3 col0" >Age_Category</td>
#       <td id="T_90d83_row3_col1" class="data row3 col1" >0.076858</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90d83_row4_col0" class="data row4 col0" >Depression</td>
#       <td id="T_90d83_row4_col1" class="data row4 col1" >0.055007</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90d83_row5_col0" class="data row5 col0" >Sex</td>
#       <td id="T_90d83_row5_col1" class="data row5 col1" >0.031941</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_90d83_row6_col0" class="data row6 col0" >Alcohol_Consumption</td>
#       <td id="T_90d83_row6_col1" class="data row6 col1" >0.030751</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_90d83_row7_col0" class="data row7 col0" >Checkup</td>
#       <td id="T_90d83_row7_col1" class="data row7 col1" >0.029959</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_90d83_row8_col0" class="data row8 col0" >Smoking_History</td>
#       <td id="T_90d83_row8_col1" class="data row8 col1" >0.026818</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_90d83_row9_col0" class="data row9 col0" >FriedPotato_Consumption</td>
#       <td id="T_90d83_row9_col1" class="data row9 col1" >0.020604</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_90d83_row10_col0" class="data row10 col0" >Fruit_Consumption</td>
#       <td id="T_90d83_row10_col1" class="data row10 col1" >0.012857</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_90d83_row11_col0" class="data row11 col0" >Green_Vegetables_Consumption</td>
#       <td id="T_90d83_row11_col1" class="data row11 col1" >0.011129</td>
#     </tr>
#     <tr>
#       <th id="T_90d83_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_90d83_row12_col0" class="data row12 col0" >Heart_Disease</td>
#       <td id="T_90d83_row12_col1" class="data row12 col1" >0.009823</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Random Forest

# %%
rf_model, rf_importance_df, rf_rmse_mean, rf_rmse_std, rf_r2 = run_random_forest(df)
print(f"Random Forest RMSE: {rf_rmse_mean:.3f}, R²: {rf_r2:.3f}")
rf_importance_df
# Out:
# Random Forest RMSE: 41.745, R²: -0.003
# <style type="text/css">
# #T_c200a_row0_col1, #T_c200a_row1_col1, #T_c200a_row2_col1, #T_c200a_row3_col1, #T_c200a_row4_col1 {
#   background-color: #90EE90;
#   font-weight: bold;
# }
# </style>
# <table id="T_c200a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c200a_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_c200a_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c200a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c200a_row0_col0" class="data row0 col0" >Green_Vegetables_Consumption</td>
#       <td id="T_c200a_row0_col1" class="data row0 col1" >0.191631</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c200a_row1_col0" class="data row1 col0" >Fruit_Consumption</td>
#       <td id="T_c200a_row1_col1" class="data row1 col1" >0.178319</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c200a_row2_col0" class="data row2 col0" >FriedPotato_Consumption</td>
#       <td id="T_c200a_row2_col1" class="data row2 col1" >0.150310</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c200a_row3_col0" class="data row3 col0" >Age_Category</td>
#       <td id="T_c200a_row3_col1" class="data row3 col1" >0.134633</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c200a_row4_col0" class="data row4 col0" >Alcohol_Consumption</td>
#       <td id="T_c200a_row4_col1" class="data row4 col1" >0.121578</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c200a_row5_col0" class="data row5 col0" >Diabetes</td>
#       <td id="T_c200a_row5_col1" class="data row5 col1" >0.046213</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c200a_row6_col0" class="data row6 col0" >Smoking_History</td>
#       <td id="T_c200a_row6_col1" class="data row6 col1" >0.034250</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c200a_row7_col0" class="data row7 col0" >Sex</td>
#       <td id="T_c200a_row7_col1" class="data row7 col1" >0.033637</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c200a_row8_col0" class="data row8 col0" >Checkup</td>
#       <td id="T_c200a_row8_col1" class="data row8 col1" >0.030563</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c200a_row9_col0" class="data row9 col0" >Depression</td>
#       <td id="T_c200a_row9_col1" class="data row9 col1" >0.024178</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c200a_row10_col0" class="data row10 col0" >Heart_Disease</td>
#       <td id="T_c200a_row10_col1" class="data row10 col1" >0.020595</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c200a_row11_col0" class="data row11 col0" >Exercise</td>
#       <td id="T_c200a_row11_col1" class="data row11 col1" >0.018175</td>
#     </tr>
#     <tr>
#       <th id="T_c200a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c200a_row12_col0" class="data row12 col0" >Arthritis</td>
#       <td id="T_c200a_row12_col1" class="data row12 col1" >0.015917</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Gradient Boosting

# %%
gb_model, gb_importance_df, gb_rmse_mean, gb_rmse_std, gb_r2 = run_gradient_boosting(df)
print(f"Gradient Boosting RMSE: {gb_rmse_mean:.3f}, R²: {gb_r2:.3f}")
gb_importance_df
# Out:
# Gradient Boosting RMSE: 36.293, R²: 0.136
# <style type="text/css">
# #T_c7231_row0_col1, #T_c7231_row1_col1, #T_c7231_row2_col1, #T_c7231_row3_col1, #T_c7231_row4_col1 {
#   background-color: #90EE90;
#   font-weight: bold;
# }
# </style>
# <table id="T_c7231">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7231_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_c7231_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7231_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7231_row0_col0" class="data row0 col0" >Diabetes</td>
#       <td id="T_c7231_row0_col1" class="data row0 col1" >0.296212</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7231_row1_col0" class="data row1 col0" >Age_Category</td>
#       <td id="T_c7231_row1_col1" class="data row1 col1" >0.272635</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7231_row2_col0" class="data row2 col0" >Exercise</td>
#       <td id="T_c7231_row2_col1" class="data row2 col1" >0.112076</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7231_row3_col0" class="data row3 col0" >Arthritis</td>
#       <td id="T_c7231_row3_col1" class="data row3 col1" >0.097415</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7231_row4_col0" class="data row4 col0" >Alcohol_Consumption</td>
#       <td id="T_c7231_row4_col1" class="data row4 col1" >0.057753</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7231_row5_col0" class="data row5 col0" >FriedPotato_Consumption</td>
#       <td id="T_c7231_row5_col1" class="data row5 col1" >0.049262</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7231_row6_col0" class="data row6 col0" >Depression</td>
#       <td id="T_c7231_row6_col1" class="data row6 col1" >0.039050</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7231_row7_col0" class="data row7 col0" >Sex</td>
#       <td id="T_c7231_row7_col1" class="data row7 col1" >0.025175</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7231_row8_col0" class="data row8 col0" >Fruit_Consumption</td>
#       <td id="T_c7231_row8_col1" class="data row8 col1" >0.017289</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7231_row9_col0" class="data row9 col0" >Green_Vegetables_Consumption</td>
#       <td id="T_c7231_row9_col1" class="data row9 col1" >0.014190</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c7231_row10_col0" class="data row10 col0" >Checkup</td>
#       <td id="T_c7231_row10_col1" class="data row10 col1" >0.010060</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c7231_row11_col0" class="data row11 col0" >Smoking_History</td>
#       <td id="T_c7231_row11_col1" class="data row11 col1" >0.008704</td>
#     </tr>
#     <tr>
#       <th id="T_c7231_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c7231_row12_col0" class="data row12 col0" >Heart_Disease</td>
#       <td id="T_c7231_row12_col1" class="data row12 col1" >0.000180</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Katere spremenljivke so pomembne?
# RF ima slabše rezultate, saj je RMSE občutno višji. Pri RF nismo uspeli dosečti zelo dobrega rezultata saj je zelo časovno zahteven in potrebuje veliko virov da pridemo do dobrega rezultata. Zato smo upoštevali rezultate XGBoost in Gradient Boosting.
#
# Pomembne spremenljivke so po XGBoost: **Diabetes**, **General_Health**, **Exercise**, **Arthritis**, **Age_Category**, **FriedPotato_Consumption**, **Depression**

# %%
important_features = ["Age_Category", "Sex", "Exercise", "Diabetes", "Arthritis", "General_Health", "FriedPotato_Consumption", "Depression"]

# %% [markdown]
# ## Regresijski modeli

# %% [markdown]
# Uporabljeni modeli so Gradient Boosting, XGBoost, Linear Regression, Ridge Regression, Random Forest. Primerjamo RMSE in r2, pri modelih dreves AIC in BIC niso smiselni zato ta korak izpustimo.

# %%
df_comparison, models = compare_models(df, important_features)
df_comparison
# Out:
#                Model RMSE (CV mean ± std)        R²  \
# 4            XGBoost       35.649 ± 0.254  0.158260
# 3  Gradient Boosting       35.651 ± 0.320  0.152378
# 0  Linear Regression       37.569 ± 0.209  0.105729
# 1   Ridge Regression       37.570 ± 0.370  0.105729
# 2      Random Forest       37.653 ± 0.400  0.099711
#
#                               Parameters
# 4  n_estimators=100, max_depth=5 [SAVED]
# 3   n_estimators=50, max_depth=3 [SAVED]
# 0                                      -
# 1                      alpha=1.0 [SAVED]
# 2           n_estimators=50, max_depth=3

# %% [markdown]
# Najboljši modeli so Gradient Boosting, XGBoost, Linear Regression in Ridge Regression. Random Forest je občutno slabši.

# %% [markdown]
# ## Vsi se gibamo
# Zanima nas kaj se zgodi če se bi vsi gibali, saj lahko to večina ljudi z lahkoto implementira v svoje življenje.

# %%
metrics_table, six_sigma_table, p_value = make_everyone_exercise(df, models["xgboost"], important_features)
metrics_table
# Out:
# Predicted BMI decreased by 0.34.
#      Metric     Before      After  Difference
# 0       MAE   4.429150   4.429673    0.000523
# 1      RMSE   5.962129   6.014610    0.052481
# 2  Mean BMI  28.662680  28.323908   -0.338772

# %%
if p_value < 0.05:
    print("Change: statistically significant")
else:
    print("Change: NOT statistically significant")
six_sigma_table
# Out:
# Change: NOT statistically significant
#         Metric         Before          After   Difference
# 0      Defects  215810.000000  214768.000000 -1042.000000
# 1         DPMO  698744.390553  695370.628193 -3373.762360
# 2  Sigma Level      -0.520793      -0.511132     0.009661

# %% [markdown]
# Več telovadbe zniža BMI ampak ni statistično signifikantno. To je problem zbirke podatkov saj ne merijo kvaliteto ali čas telovadbe, ampak samo če si v zadnjem času telovadil.

# %% [markdown]
# # Ugotovitve
# Najbolj pomembne spremenljivke so diabetis, ocena splošnega zdravja, gibanje, artritis, starost. Malo manj pomembne so če imamo depresijo in če konzumiramo večje količine cvrtega krompirja.
#
# - Diabetes: ljudje s prekomerno telesno težo so bolj nagnjeni k temu da razvijejo diabetes.
# - Ocena splošnega zdravja: ljudje s slabšim splošnim zdravjem imajo lahko omejeno gibanje ali slabše diete, kar vpliva na telesno težo.
# - Telovadba: redna telesna aktivnost neposredno vpliva na porabo kalorij kar pomeni manjšo telesno težo.
# - Artritis: artritis lahko omeji telesno aktivnost, kar lahko vodi do povečanja teže.
# - Starost: starejši ljudje imajo manj energije za aktivnost ali pa imajo druge bolezni ki vodijo do povečanja teže
# - Depresija: lahko povzroči spremembe apetita in aktivnosti, kar posredno vpliva na telesno težo.
# - Konzumacija cvrtga krompirja: če jejo več visokokaloričnega krompirja, je možnost da jejo več na splošno
#
# ## Pozitivni in negativni vplivi na BMI
# Več gibanja ima pozitivni vpliv na BMI, torej ga zmanjša, prav tako ima pozitivni vpliv dobra ocena splošnega zdravja. Za binarne spremenljivke velja da če so resnične, višajo BMI. Višja starost viša BMI. Pogosta konzumacija cvrtega krompirja viša BMI.
#
# ## Zakaj je težko napovedati BMI?
# Podatkovna zbirka ni bila narejena za napoved BMI. Pri konzumpciji hrane ni navedeno koliko jo pojejo, prav tako pri gibanju ni navedeno koliko se gibajo oz. kako kvalitetno je to gibanje za kurjenje maščobe. Ocena splošnega zdravja je lahko problematična saj je popolnoma subjektivna s strani pacienta, prav tako depresija. Problem pri binarnih spremenljivkah je da jih je večina zelo nagnjena k eni vrednosti.
